# %% [markdown]
# ### Import external modules

# %%
import gym
import matplotlib.pyplot as plt
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecMonitor

# %% [markdown]
# ### Add mbt-gym to path

# %%
import sys
sys.path.append("../")

# %%
from mbt_gym.agents.BaselineAgents import CarteaJaimungalAgent
from mbt_gym.gym.helpers.generate_trajectory import generate_trajectory
from mbt_gym.gym.StableBaselinesTradingEnvironment import StableBaselinesTradingEnvironment
from mbt_gym.gym.TradingEnvironment import TradingEnvironment
from mbt_gym.gym.wrappers import *
from mbt_gym.rewards.RewardFunctions import CjCriterion
from mbt_gym.stochastic_processes.midprice_models import *
from mbt_gym.stochastic_processes.fill_probability_models import *
from mbt_gym.stochastic_processes.arrival_models import *

# %% [markdown]
# ### Add parameters for limit order market making environment

# %%
terminal_time = 1.0
arrival_rate = 10.0
n_steps = int(10 * terminal_time * arrival_rate)
phi = 0.5
alpha = 0.001

# %%
def get_cj_env(num_trajectories:int = 1):    
    fill_exponent = 1
    sigma = 0.1
    initial_inventory = (-4,5)
    initial_price = 100
    step_size = 1/n_steps
    timestamps = np.linspace(0, terminal_time, n_steps + 1)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      initial_inventory = initial_inventory,
                      midprice_model = BrownianMotionMidpriceModel(volatility=sigma, 
                                                                   terminal_time=terminal_time, 
                                                                   step_size=step_size, 
                                                                   initial_price=initial_price, 
                                                                   num_trajectories=num_trajectories),
                      arrival_model = HawkesArrivalModel(num_trajectories=num_trajectories),
                      fill_probability_model = ExponentialFillFunction(fill_exponent=fill_exponent, 
                                                                       step_size=step_size, 
                                                                       num_trajectories=num_trajectories),
                      reward_function = CjCriterion(phi, alpha),
                      max_inventory=n_steps,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
num_trajectories = 10000
env = ReduceStateSizeWrapper(get_cj_env(num_trajectories), [1,2,4,5])
sb_env = StableBaselinesTradingEnvironment(trading_env=env)

# %%
# Monitor sb_env
sb_env = VecMonitor(sb_env)
# Add directory for tensorboard logging 
tensorboard_logdir = "./tensorboard/PPO-learning-Hawkes/"
best_model_path = "./SB_models/PPO-best-Hawkes"

# %% [markdown]
# ### Define PPO policy

# %%
policy_kwargs = dict(net_arch=[dict(pi=[64, 64], vf=[128, 128])])
PPO_params = {"policy":'MlpPolicy', "env": sb_env, "verbose":1, 
              "policy_kwargs":policy_kwargs, 
              "tensorboard_log":tensorboard_logdir,
              "batch_size": int(n_steps * num_trajectories / 20), 
              "n_steps": int(n_steps)} #256 before (batch size)
callback_params = dict(eval_env=sb_env, n_eval_episodes = 2048, 
                       eval_freq = 1000000*5,#200 before  (n_eval_episodes)
                       best_model_save_path = best_model_path, 
                       deterministic=True)

callback = EvalCallback(**callback_params)
model = PPO(**PPO_params, device="cpu")
# Out:
# Using cpu device

# %%
model.learn(total_timesteps = 100_000_000)
# Out:
# Logging to ./tensorboard/PPO-learning-Hawkes/PPO_2
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | -34.26258 |
# | time/              |           |
# |    fps             | 739049    |
# |    iterations      | 1         |
# |    time_elapsed    | 1         |
# |    total_timesteps | 1000000   |
# ----------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -32.782173   |
# | time/                   |              |
# |    fps                  | 63059        |
# |    iterations           | 2            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 2000000      |
# | train/                  |              |
# |    approx_kl            | 0.0031613272 |
# |    clip_fraction        | 0.0164       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.000167    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.1         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00111     |
# |    std                  | 1            |
# |    value_loss           | 72.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -21.548244  |
# | time/                   |             |
# |    fps                  | 48342       |
# |    iterations           | 3           |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 3000000     |
# | train/                  |             |
# |    approx_kl            | 0.003670577 |
# |    clip_fraction        | 0.0215      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 0.368       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.8        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00161    |
# |    std                  | 0.997       |
# |    value_loss           | 57.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -19.261053 |
# | time/                   |            |
# |    fps                  | 43265      |
# |    iterations           | 4          |
# |    time_elapsed         | 92         |
# |    total_timesteps      | 4000000    |
# | train/                  |            |
# |    approx_kl            | 0.00436991 |
# |    clip_fraction        | 0.0282     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.82      |
# |    explained_variance   | 0.535      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 24.2       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.00213   |
# |    std                  | 0.991      |
# |    value_loss           | 53         |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -15.321049   |
# | time/                   |              |
# |    fps                  | 40939        |
# |    iterations           | 5            |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 5000000      |
# | train/                  |              |
# |    approx_kl            | 0.0045709563 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.6          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.7         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00252     |
# |    std                  | 0.985        |
# |    value_loss           | 49.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -9.086213    |
# | time/                   |              |
# |    fps                  | 39424        |
# |    iterations           | 6            |
# |    time_elapsed         | 152          |
# |    total_timesteps      | 6000000      |
# | train/                  |              |
# |    approx_kl            | 0.0046743318 |
# |    clip_fraction        | 0.0385       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.637        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.5         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00284     |
# |    std                  | 0.977        |
# |    value_loss           | 44.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -9.564216   |
# | time/                   |             |
# |    fps                  | 38365       |
# |    iterations           | 7           |
# |    time_elapsed         | 182         |
# |    total_timesteps      | 7000000     |
# | train/                  |             |
# |    approx_kl            | 0.005131027 |
# |    clip_fraction        | 0.0431      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.662       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.8        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00314    |
# |    std                  | 0.969       |
# |    value_loss           | 34.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -7.257157    |
# | time/                   |              |
# |    fps                  | 37624        |
# |    iterations           | 8            |
# |    time_elapsed         | 212          |
# |    total_timesteps      | 8000000      |
# | train/                  |              |
# |    approx_kl            | 0.0053505814 |
# |    clip_fraction        | 0.0458       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.76        |
# |    explained_variance   | 0.679        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.9         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00347     |
# |    std                  | 0.959        |
# |    value_loss           | 28.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 2.2291458   |
# | time/                   |             |
# |    fps                  | 37025       |
# |    iterations           | 9           |
# |    time_elapsed         | 243         |
# |    total_timesteps      | 9000000     |
# | train/                  |             |
# |    approx_kl            | 0.005572884 |
# |    clip_fraction        | 0.0498      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | 0.685       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.9        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00367    |
# |    std                  | 0.949       |
# |    value_loss           | 22.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0.8456483   |
# | time/                   |             |
# |    fps                  | 36662       |
# |    iterations           | 10          |
# |    time_elapsed         | 272         |
# |    total_timesteps      | 10000000    |
# | train/                  |             |
# |    approx_kl            | 0.005639132 |
# |    clip_fraction        | 0.0497      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.71       |
# |    explained_variance   | 0.687       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.97        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00375    |
# |    std                  | 0.938       |
# |    value_loss           | 18.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -0.038643017 |
# | time/                   |              |
# |    fps                  | 36338        |
# |    iterations           | 11           |
# |    time_elapsed         | 302          |
# |    total_timesteps      | 11000000     |
# | train/                  |              |
# |    approx_kl            | 0.0056982283 |
# |    clip_fraction        | 0.0514       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.69        |
# |    explained_variance   | 0.687        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.08         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00371     |
# |    std                  | 0.926        |
# |    value_loss           | 14           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 3.9785705   |
# | time/                   |             |
# |    fps                  | 36057       |
# |    iterations           | 12          |
# |    time_elapsed         | 332         |
# |    total_timesteps      | 12000000    |
# | train/                  |             |
# |    approx_kl            | 0.005764551 |
# |    clip_fraction        | 0.0527      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.66       |
# |    explained_variance   | 0.678       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.57        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0038     |
# |    std                  | 0.914       |
# |    value_loss           | 11.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 5.0380793    |
# | time/                   |              |
# |    fps                  | 35759        |
# |    iterations           | 13           |
# |    time_elapsed         | 363          |
# |    total_timesteps      | 13000000     |
# | train/                  |              |
# |    approx_kl            | 0.0055909557 |
# |    clip_fraction        | 0.0503       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.63        |
# |    explained_variance   | 0.657        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.22         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00386     |
# |    std                  | 0.902        |
# |    value_loss           | 8.28         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 5.592876     |
# | time/                   |              |
# |    fps                  | 35625        |
# |    iterations           | 14           |
# |    time_elapsed         | 392          |
# |    total_timesteps      | 14000000     |
# | train/                  |              |
# |    approx_kl            | 0.0056089493 |
# |    clip_fraction        | 0.0491       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.6         |
# |    explained_variance   | 0.647        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.1          |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00359     |
# |    std                  | 0.887        |
# |    value_loss           | 6.37         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.7313414    |
# | time/                   |              |
# |    fps                  | 35464        |
# |    iterations           | 15           |
# |    time_elapsed         | 422          |
# |    total_timesteps      | 15000000     |
# | train/                  |              |
# |    approx_kl            | 0.0051625376 |
# |    clip_fraction        | 0.041        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.57        |
# |    explained_variance   | 0.638        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.64         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00343     |
# |    std                  | 0.874        |
# |    value_loss           | 5.31         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 9.494466     |
# | time/                   |              |
# |    fps                  | 35381        |
# |    iterations           | 16           |
# |    time_elapsed         | 452          |
# |    total_timesteps      | 16000000     |
# | train/                  |              |
# |    approx_kl            | 0.0048976894 |
# |    clip_fraction        | 0.0385       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.54        |
# |    explained_variance   | 0.646        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.19         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00307     |
# |    std                  | 0.862        |
# |    value_loss           | 4.45         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 9.823589     |
# | time/                   |              |
# |    fps                  | 35314        |
# |    iterations           | 17           |
# |    time_elapsed         | 481          |
# |    total_timesteps      | 17000000     |
# | train/                  |              |
# |    approx_kl            | 0.0049231322 |
# |    clip_fraction        | 0.0377       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.51        |
# |    explained_variance   | 0.62         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.8          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00284     |
# |    std                  | 0.848        |
# |    value_loss           | 3.67         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 9.697319    |
# | time/                   |             |
# |    fps                  | 35123       |
# |    iterations           | 18          |
# |    time_elapsed         | 512         |
# |    total_timesteps      | 18000000    |
# | train/                  |             |
# |    approx_kl            | 0.003999311 |
# |    clip_fraction        | 0.0294      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.48       |
# |    explained_variance   | 0.627       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.61        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00239    |
# |    std                  | 0.836       |
# |    value_loss           | 3.25        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 9.485348     |
# | time/                   |              |
# |    fps                  | 34994        |
# |    iterations           | 19           |
# |    time_elapsed         | 542          |
# |    total_timesteps      | 19000000     |
# | train/                  |              |
# |    approx_kl            | 0.0038289689 |
# |    clip_fraction        | 0.0238       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.45        |
# |    explained_variance   | 0.637        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.46         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00182     |
# |    std                  | 0.822        |
# |    value_loss           | 2.9          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 11.384208    |
# | time/                   |              |
# |    fps                  | 34902        |
# |    iterations           | 20           |
# |    time_elapsed         | 573          |
# |    total_timesteps      | 20000000     |
# | train/                  |              |
# |    approx_kl            | 0.0037569038 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.42        |
# |    explained_variance   | 0.651        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.39         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00176     |
# |    std                  | 0.81         |
# |    value_loss           | 2.82         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 11.046974    |
# | time/                   |              |
# |    fps                  | 34848        |
# |    iterations           | 21           |
# |    time_elapsed         | 602          |
# |    total_timesteps      | 21000000     |
# | train/                  |              |
# |    approx_kl            | 0.0027924706 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.38        |
# |    explained_variance   | 0.659        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.33         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00136     |
# |    std                  | 0.793        |
# |    value_loss           | 2.68         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 12.415962    |
# | time/                   |              |
# |    fps                  | 34758        |
# |    iterations           | 22           |
# |    time_elapsed         | 632          |
# |    total_timesteps      | 22000000     |
# | train/                  |              |
# |    approx_kl            | 0.0029573548 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.34        |
# |    explained_variance   | 0.666        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.35         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00119     |
# |    std                  | 0.778        |
# |    value_loss           | 2.7          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 11.8574705   |
# | time/                   |              |
# |    fps                  | 34714        |
# |    iterations           | 23           |
# |    time_elapsed         | 662          |
# |    total_timesteps      | 23000000     |
# | train/                  |              |
# |    approx_kl            | 0.0029741249 |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.31        |
# |    explained_variance   | 0.668        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.37         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000772    |
# |    std                  | 0.765        |
# |    value_loss           | 2.7          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 11.317639    |
# | time/                   |              |
# |    fps                  | 34670        |
# |    iterations           | 24           |
# |    time_elapsed         | 692          |
# |    total_timesteps      | 24000000     |
# | train/                  |              |
# |    approx_kl            | 0.0034436123 |
# |    clip_fraction        | 0.0151       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.27        |
# |    explained_variance   | 0.672        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.36         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000978    |
# |    std                  | 0.749        |
# |    value_loss           | 2.7          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 12.678344    |
# | time/                   |              |
# |    fps                  | 34628        |
# |    iterations           | 25           |
# |    time_elapsed         | 721          |
# |    total_timesteps      | 25000000     |
# | train/                  |              |
# |    approx_kl            | 0.0027002285 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.22        |
# |    explained_variance   | 0.684        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.33         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000961    |
# |    std                  | 0.733        |
# |    value_loss           | 2.62         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 12.440583    |
# | time/                   |              |
# |    fps                  | 34606        |
# |    iterations           | 26           |
# |    time_elapsed         | 751          |
# |    total_timesteps      | 26000000     |
# | train/                  |              |
# |    approx_kl            | 0.0033996017 |
# |    clip_fraction        | 0.0134       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.19        |
# |    explained_variance   | 0.684        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.35         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000669    |
# |    std                  | 0.721        |
# |    value_loss           | 2.73         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 12.302288   |
# | time/                   |             |
# |    fps                  | 34515       |
# |    iterations           | 27          |
# |    time_elapsed         | 782         |
# |    total_timesteps      | 27000000    |
# | train/                  |             |
# |    approx_kl            | 0.002088644 |
# |    clip_fraction        | 0.0208      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | 0.688       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.37        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.000198   |
# |    std                  | 0.704       |
# |    value_loss           | 2.73        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 12.8410225  |
# | time/                   |             |
# |    fps                  | 34485       |
# |    iterations           | 28          |
# |    time_elapsed         | 811         |
# |    total_timesteps      | 28000000    |
# | train/                  |             |
# |    approx_kl            | 0.002007539 |
# |    clip_fraction        | 0.00928     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.693       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.36        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.000639   |
# |    std                  | 0.689       |
# |    value_loss           | 2.7         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 13.643313    |
# | time/                   |              |
# |    fps                  | 34437        |
# |    iterations           | 29           |
# |    time_elapsed         | 842          |
# |    total_timesteps      | 29000000     |
# | train/                  |              |
# |    approx_kl            | 0.0032555622 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.06        |
# |    explained_variance   | 0.692        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.4          |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000581    |
# |    std                  | 0.676        |
# |    value_loss           | 2.79         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 13.7441225  |
# | time/                   |             |
# |    fps                  | 34391       |
# |    iterations           | 30          |
# |    time_elapsed         | 872         |
# |    total_timesteps      | 30000000    |
# | train/                  |             |
# |    approx_kl            | 0.002499837 |
# |    clip_fraction        | 0.0103      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0.701       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.4         |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.000511   |
# |    std                  | 0.664       |
# |    value_loss           | 2.77        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 13.748887    |
# | time/                   |              |
# |    fps                  | 34352        |
# |    iterations           | 31           |
# |    time_elapsed         | 902          |
# |    total_timesteps      | 31000000     |
# | train/                  |              |
# |    approx_kl            | 0.0019699864 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.98        |
# |    explained_variance   | 0.699        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.42         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000567    |
# |    std                  | 0.649        |
# |    value_loss           | 2.81         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 13.6604805   |
# | time/                   |              |
# |    fps                  | 34300        |
# |    iterations           | 32           |
# |    time_elapsed         | 932          |
# |    total_timesteps      | 32000000     |
# | train/                  |              |
# |    approx_kl            | 0.0018713565 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.708        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.39         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.000452    |
# |    std                  | 0.638        |
# |    value_loss           | 2.8          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 12.464448    |
# | time/                   |              |
# |    fps                  | 34245        |
# |    iterations           | 33           |
# |    time_elapsed         | 963          |
# |    total_timesteps      | 33000000     |
# | train/                  |              |
# |    approx_kl            | 0.0021461684 |
# |    clip_fraction        | 0.00875      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.91        |
# |    explained_variance   | 0.704        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.42         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000504    |
# |    std                  | 0.627        |
# |    value_loss           | 2.84         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 15.0237465   |
# | time/                   |              |
# |    fps                  | 34182        |
# |    iterations           | 34           |
# |    time_elapsed         | 994          |
# |    total_timesteps      | 34000000     |
# | train/                  |              |
# |    approx_kl            | 0.0019791457 |
# |    clip_fraction        | 0.00619      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | 0.699        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.44         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0004      |
# |    std                  | 0.614        |
# |    value_loss           | 2.9          |
# ------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 model.learn(total_timesteps = 100_000_000)
#
# File ~/.pyenv/versions/3.9.13/envs/mbt_gym/lib/python3.9/site-packages/stable_baselines3/ppo/ppo.py:304, in PPO.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     291 def learn(
#     292     self,
#     293     total_timesteps: int,
#    (...)
#     301     reset_num_timesteps: bool = True,
#     302 ) -> "PPO":
# --> 304     return super(PPO, self).learn(
#     305         total_timesteps=total_timesteps,
#     306         callback=callback,
#     307         log_interval=log_interval,
#     308         eval_env=eval_env,
#     309         eval_freq=eval_freq,
#     310         n_eval_episodes=n_eval_episodes,
#     311         tb_log_name=tb_log_name,
#     312         eval_log_path=eval_log_path,
#     313         reset_num_timesteps=reset_num_timesteps,
#     314     )
#
# File ~/.pyenv/versions/3.9.13/envs/mbt_gym/lib/python3.9/site-packages/stable_baselines3/common/on_policy_algorithm.py:270, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     267         self.logger.record("time/total_timesteps", self.num_timesteps, exclude="tensorboard")
#     268         self.logger.dump(step=self.num_timesteps)
# --> 270     self.train()
#     272 callback.on_training_end()
#     274 return self
#
# File ~/.pyenv/versions/3.9.13/envs/mbt_gym/lib/python3.9/site-packages/stable_baselines3/ppo/ppo.py:264, in PPO.train(self)
#     262 # Optimization step
#     263 self.policy.optimizer.zero_grad()
# --> 264 loss.backward()
#     265 # Clip grad norm
#     266 th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#
# File ~/.pyenv/versions/3.9.13/envs/mbt_gym/lib/python3.9/site-packages/torch/_tensor.py:363, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     354 if has_torch_function_unary(self):
#     355     return handle_torch_function(
#     356         Tensor.backward,
#     357         (self,),
#    (...)
#     361         create_graph=create_graph,
#     362         inputs=inputs)
# --> 363 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~/.pyenv/versions/3.9.13/envs/mbt_gym/lib/python3.9/site-packages/torch/autograd/__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Comparing the learnt policy to the optimal policy

# %%
from mbt_gym.agents.SbAgent import SbAgent

# %%
agent = SbAgent(model)

# %%
inventories = np.arange(-3,4,1)
bid_actions = {}
ask_actions = {}
intensities=[5,10,20]
for intensity in intensities:
    bid_actions[intensity] = []
    ask_actions[intensity] = []
    for inventory in inventories:
        bid_action, ask_action = np.reshape(model.predict([inventory,0.5, intensity, intensity], deterministic=True)[0], 2)    
        bid_actions[intensity].append(bid_action)
        ask_actions[intensity].append(ask_action)

# %%
cj_agent = CarteaJaimungalAgent(phi = phi, alpha= alpha, env=get_cj_env())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 cj_agent = CarteaJaimungalAgent(phi = phi, alpha= alpha, env=get_cj_env())
#
# File ~/Documents/github/mbt_gym/notebooks/../mbt_gym/agents/BaselineAgents.py:93, in CarteaJaimungalAgent.__init__(self, phi, alpha, env, max_inventory)
#      91 assert self.env.action_type == "limit"
#      92 self.terminal_time = self.env.terminal_time
# ---> 93 self.lambdas = self.env.arrival_model.intensity
#      94 self.kappa = self.env.fill_probability_model.fill_exponent
#      95 self.max_inventory = max_inventory
#
# AttributeError: 'HawkesArrivalModel' object has no attribute 'intensity'

# %%
# Get the Cartea Jaimungal action
cj_bid_actions = []
cj_ask_actions = []
for inventory in inventories:
    bid_action, ask_action = cj_agent.get_action(np.array([[0,inventory,0.5]])).reshape(-1)
    cj_bid_actions.append(bid_action)
    cj_ask_actions.append(ask_action)

# %%
bid_actions
# Out:
# {5: [0.0072848015,
#   0.35005736,
#   0.7466455,
#   1.1158242,
#   1.4032677,
#   1.5810778,
#   1.6487743],
#  10: [0.2548936,
#   0.54536235,
#   0.8902156,
#   1.2266855,
#   1.49812,
#   1.6753762,
#   1.751526],
#  20: [0.36665395,
#   0.65743047,
#   0.99293447,
#   1.3213042,
#   1.5955714,
#   1.7903905,
#   1.8989378]}

# %%
colors = ["k", "r", "b"]

for i, intensity in enumerate(intensities):
    plt.plot(inventories, bid_actions[intensity], label = f"bid - lambda = {intensity}", color = colors[i])
    plt.plot(inventories, ask_actions[intensity], label = f"ask - lambda = {intensity}", color = colors[i], linestyle = "--")
plt.legend()

# %%
timestamps = np.arange(0,1 + 0.01, 0.01)

# %%
bid_actions = {}
ask_actions = {}
for inventory in inventories:
    bid_actions[inventory] = []
    ask_actions[inventory] = []
    for timestamp in timestamps:
        bid_action, ask_action = agent.get_action(np.array([inventory, timestamp]))
        bid_actions[inventory].append(bid_action)
        ask_actions[inventory].append(ask_action)

# %%
for inventory in inventories:
    plt.plot(timestamps, bid_actions[inventory], label=f"bid: q = {inventory}")
plt.legend()
plt.show()

# %%
for inventory in inventories:
    plt.plot(timestamps, ask_actions[inventory], label=f"ask: q = {inventory}")
plt.legend()
plt.show()

# %%
model.save("trained_model")

# %%
loaded = PPO.load("trained_model.zip")

# %%
loaded
